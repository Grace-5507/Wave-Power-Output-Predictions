# %%
import pandas as pd
import os
import seaborn as sns
import zipfile
import numpy as np
import matplotlib.pyplot as plt

# %%
zip_filepath = ('large-scale+wave+energy+farm.zip')
extract_dir = 'unzipped_data'


with zipfile.ZipFile(zip_filepath, "r") as zip_ref:
    zip_ref.extractall(etract_dir)

print(os.listdir(extract_dir ))
# Out:
# ['WEC.zip', 'WEC_Perth_49.csv']

# %%
zip_filepath = 'unzipped_data/WEC.zip'
extract_dir = 'unzipped_data'

with zipfile.ZipFile(zip_filepath, "r") as z_ref:
    z_ref.extractall(extract_dir)
print(os.listdir(extract_dir ))
# Out:
# ['WEC.zip', 'WEC', 'WEC_Perth_49.csv']

# %%
zip_filepath = 'unzipped_data/WEC.zip'
extract_dir = 'unzipped_data'

with zipfile.ZipFile(zip_filepath, "r") as _ref:
    _ref.extractall(extract_dir)
print(os.listdir(extract_dir ))
# Out:
# ['WEC.zip', 'WEC', 'WEC_Perth_49.csv']

# %%
zip_filepath = 'unzipped_data/WEC.zip'
extract_dir = 'unzipped_data'

with zipfile.ZipFile(zip_filepath, "r") as _ref:
    _ref.extractall(extract_dir)
print(os.listdir('unzipped_data/WEC' ))
# Out:
# ['WEC_Sydney_49.csv', 'WEC_Sydney_100.csv', 'WEC_Perth_49.csv', 'WEC_Perth_100.csv']

# %%
df_SD49 = pd.read_csv('unzipped_data/WEC/WEC_Sydney_49.csv')

# %%
df_SD100 = pd.read_csv('unzipped_data/WEC/WEC_Sydney_100.csv')

# %%
df_PT49 = pd.read_csv('unzipped_data/WEC/WEC_Perth_49.csv')

# %%
df_PT100= pd.read_csv('unzipped_data/WEC/WEC_Perth_100.csv')

# %%
df_SD49.info()
df_SD49.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17964 entries, 0 to 17963
# Columns: 149 entries, X1 to Total_Power
# dtypes: float64(149)
# memory usage: 20.4 MB
#       X1   Y1      X2     Y2      X3     Y3      X4     Y4     X5     Y5  ...  \
# 0    1.0  1.0    0.00  70.00    1.00  140.0   50.00  198.0  401.0    1.0  ...
# 1  598.0  0.0  595.82  77.69  593.70  150.0  549.00  198.0  798.0    0.0  ...
# 2  198.0  0.0  197.46  75.19  192.94  150.0   87.64  198.0  398.0    0.0  ...
# 3  598.0  0.0  596.97  69.41  592.69  143.8  549.00  198.0  398.0  200.0  ...
# 4  198.0  0.0  197.18  79.83  192.97  150.0   89.53  198.0  398.0    0.0  ...
#
#     Power42   Power43   Power44   Power45   Power46   Power47   Power48  \
# 0  71909.82  70674.49  70972.33  90957.03  90903.63  87876.82  79499.23
# 1  68757.68  70665.50  69963.48  84511.25  85691.70  85211.51  76678.20
# 2  73675.80  77808.44  73519.82  91436.35  88770.60  86632.78  77932.46
# ...

# %%
df_SD100.info()
df_SD100.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2318 entries, 0 to 2317
# Columns: 302 entries, X1 to Total_Power
# dtypes: float64(302)
# memory usage: 5.3 MB
#       X1   Y1      X2     Y2      X3      Y3      X4     Y4     X5   Y5  ...  \
# 0    1.0  1.0    1.00  51.00    1.00  101.00    1.00  151.0  398.0  0.0  ...
# 1  198.0  0.0  197.18  80.53  193.59  150.00   77.58  198.0  598.0  0.0  ...
# 2  198.0  0.0  197.07  76.64  192.74  155.74   84.67  198.0  798.0  0.0  ...
# 3    1.0  1.0    1.00  51.00    1.00  101.00    1.00  151.0  398.0  0.0  ...
# 4  198.0  0.0  197.46  75.07  197.18  149.14  149.00  198.0  598.0  0.0  ...
#
#     Power93   Power94   Power95   Power96   Power97   Power98   Power99  \
# 0  74018.52  71727.79  67966.45  63101.26  88826.02  86531.44  83786.68
# 1  63702.46  67776.99  65133.52  63138.74  82852.91  83519.30  81973.65
# 2  55788.34  59593.98  60073.60  59198.12  63377.08  72078.85  77435.62
# ...

# %%
df_PT49.info()
df_PT49.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36043 entries, 0 to 36042
# Columns: 149 entries, X1 to Total_Power
# dtypes: float64(149)
# memory usage: 41.0 MB
#       X1    Y1      X2     Y2      X3     Y3      X4      Y4     X5   Y5  ...  \
# 0  600.0   0.0  546.16  37.50  489.79  74.88  432.47  112.05  650.0  0.0  ...
# 1  593.0  12.0  546.16  37.50  489.79  74.88  432.47  112.05  644.0  8.0  ...
# 2  593.0  12.0  546.16  37.50  489.79  74.88  432.47  112.05  644.0  8.0  ...
# 3  593.0  12.0  546.16  37.50  489.79  74.88  432.47  112.05  644.0  8.0  ...
# 4  200.0   0.0  146.17  37.53   89.76  74.93   32.40  112.18  400.0  0.0  ...
#
#     Power42   Power43    Power44   Power45    Power46    Power47   Power48  \
# 0  88867.92  98844.30  101283.59  98934.63  101624.58  100915.03  99625.68
# 1  88896.55  98759.79  101346.07  98873.59  101629.01  100934.53  99606.13
# 2  88919.83  98746.68  101346.15  98875.57  101618.32  100941.00  99611.35
# ...

# %%
df_PT100.info()
df_PT100.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7277 entries, 0 to 7276
# Columns: 302 entries, X1 to Total_Power
# dtypes: float64(302)
# memory usage: 16.8 MB
#        X1   Y1      X2     Y2      X3     Y3      X4      Y4      X5   Y5  \
# 0  1000.0  0.0  946.08  37.42  889.67  74.76  832.02  112.10  1250.0  1.0
# 1   800.0  0.0  746.04  37.38  689.81  74.79  632.43  111.97  1200.0  0.0
# 2   600.0  0.0  545.98  37.50  489.87  74.95  432.52  112.15   650.0  0.0
# 3   600.0  0.0  546.09  37.41  489.70  74.76  432.35  111.90   800.0  0.0
# 4   600.0  0.0  545.95  37.52  489.69  74.99  432.46  112.16   800.0  0.0
#
#    ...   Power93    Power94    Power95    Power96   Power97    Power98  \
# 0  ...  98711.68  102872.82  100743.44   99259.87  98909.46  101388.37
# 1  ...  96351.38  102253.02  101744.20   99482.45  99304.59  101953.23
# 2  ...  96985.29  102472.80  101757.63   99429.45  98709.14  101312.44
# 3  ...  76823.85   88005.41   98779.92  100260.30  98744.25  101144.58
# ...

# %%
df_SD49.dtypes
# Out:
# X1             float64
# Y1             float64
# X2             float64
# Y2             float64
# X3             float64
#                 ...
# Power47        float64
# Power48        float64
# Power49        float64
# qW             float64
# Total_Power    float64
# Length: 149, dtype: object

# %%
df_SD49.index
# Out:
# RangeIndex(start=0, stop=17964, step=1)

# %%
df_SD49.columns
# Out:
# Index(['X1', 'Y1', 'X2', 'Y2', 'X3', 'Y3', 'X4', 'Y4', 'X5', 'Y5',
#        ...
#        'Power42', 'Power43', 'Power44', 'Power45', 'Power46', 'Power47',
#        'Power48', 'Power49', 'qW', 'Total_Power'],
#       dtype='object', length=149)

# %%
for i in df_SD49.columns

# %%
df_SD49.loc[:, ["X1", "Y1"]]
# Out:
#           X1     Y1
# 0        1.0    1.0
# 1      598.0    0.0
# 2      198.0    0.0
# 3      598.0    0.0
# 4      198.0    0.0
# ...      ...    ...
# 17959    1.0  198.0
# 17960  398.0    0.0
# 17961    1.0    1.0
# 17962    1.0    1.0
# 17963  198.0    0.0
#
# [17964 rows x 2 columns]

# %%
df_SD49.loc[:, ["X49", "Y49"]]
# Out:
#        X49     Y49
# 0      0.0  1000.0
# 1      0.0  1000.0
# 2      0.0  1000.0
# 3      0.0  1000.0
# 4      0.0  1000.0
# ...    ...     ...
# 17959  0.0  1010.0
# 17960  0.0  1000.0
# 17961  0.0  1000.0
# 17962  0.0  1000.0
# 17963  0.0  1010.0
#
# [17964 rows x 2 columns]

# %%
df_SD100.loc[:, ["X100", "Y100"]]
# Out:
#          X100    Y100
# 0     1349.00  1398.0
# 1     1277.58  1398.0
# 2     1084.67  1398.0
# 3     1349.00  1398.0
# 4      949.00  1398.0
# ...       ...     ...
# 2313   484.79  1398.0
# 2314   699.00  1403.0
# 2315  1149.00  1398.0
# 2316  1277.58  1398.0
# 2317  1149.00  1398.0
#
# [2318 rows x 2 columns]

# %%
#RESHAPING

# %%
position = []

for i, row in df_SD49.iterrows():
    n = len([col for col in df_SD49.columns if col.startswith("X")])
    for j in range(n):
        x=row[f"X{j+1}"]
        y=row[f"Y{j+1}"]
        p=row[f"Power{j+1}"]
        position.append([x,y,p])

pos_df = pd.DataFrame(position, columns=["X", "Y", "Power"])

pos_df
# Out:
#              X        Y      Power
# 0         1.00     1.00   93963.49
# 1         0.00    70.00   85970.88
# 2         1.00   140.00   80886.23
# 3        50.00   198.00   76743.70
# 4       401.00     1.00  100009.42
# ...        ...      ...        ...
# 880231  998.00   800.00   86024.36
# 880232  996.79   873.55   86504.53
# 880233  997.18   947.45   86728.45
# 880234  949.00   998.00   79660.05
# 880235    0.00  1010.00   78190.24
#
# [880236 rows x 3 columns]

# %%
# Scatter plot: position vs power
plt.figure(figsize=(8,6))
plt.scatter(pos_df["X"], pos_df["Y"], c=pos_df["Power"], cmap="viridis", alpha=0.7)
plt.colorbar(label="WEC Power Output")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.title("Individual WEC Positions vs Power Output")
plt.show()

# %%
heatmap, xedges, yedges = np.histogram2d(pos_df["X"], pos_df["Y"],
                                         bins=50, weights=pos_df["Power"])
counts, _, _ = np.histogram2d(pos_df["X"], pos_df["Y"], bins=50)
avg_power = heatmap / np.maximum(counts, 1)

plt.imshow(avg_power.T, origin='lower', cmap="inferno",
           extent=[pos_df["X"].min(), pos_df["X"].max(),
                   pos_df["Y"].min(), pos_df["Y"].max()])
plt.colorbar(label="Average WEC Power")
plt.xlabel("X Position")
plt.ylabel("Y Position")
plt.title("High-Power WEC Position Heatmap")
plt.show()

# %%
NOTE:Brightest spots are the best possitions for highest outputs

# %%
sns.heatmap(df.corr(), annot=True,cmap='coolwarm')
